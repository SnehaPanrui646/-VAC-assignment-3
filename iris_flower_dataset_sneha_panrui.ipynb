# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats
import pandas as pd
df=pd.read_csv("/content/iris.csv")
df
# Out:
#      150    4  setosa  versicolor  virginica
# 0    5.1  3.5     1.4         0.2          0
# 1    4.9  3.0     1.4         0.2          0
# 2    4.7  3.2     1.3         0.2          0
# 3    4.6  3.1     1.5         0.2          0
# 4    5.0  3.6     1.4         0.2          0
# ..   ...  ...     ...         ...        ...
# 145  6.7  3.0     5.2         2.3          2
# 146  6.3  2.5     5.0         1.9          2
# 147  6.5  3.0     5.2         2.0          2
# 148  6.2  3.4     5.4         2.3          2
# 149  5.9  3.0     5.1         1.8          2
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    150    4  setosa  versicolor  virginica
# 0  5.1  3.5     1.4         0.2          0
# 1  4.9  3.0     1.4         0.2          0
# 2  4.7  3.2     1.3         0.2          0
# 3  4.6  3.1     1.5         0.2          0
# 4  5.0  3.6     1.4         0.2          0

# %%
df.tail(7)
# Out:
#      150    4  setosa  versicolor  virginica
# 143  6.8  3.2     5.9         2.3          2
# 144  6.7  3.3     5.7         2.5          2
# 145  6.7  3.0     5.2         2.3          2
# 146  6.3  2.5     5.0         1.9          2
# 147  6.5  3.0     5.2         2.0          2
# 148  6.2  3.4     5.4         2.3          2
# 149  5.9  3.0     5.1         1.8          2

# %%
df.describe()
# Out:
#               150           4      setosa  versicolor   virginica
# count  150.000000  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333    1.000000
# std      0.828066    0.435866    1.765298    0.762238    0.819232
# min      4.300000    2.000000    1.000000    0.100000    0.000000
# 25%      5.100000    2.800000    1.600000    0.300000    0.000000
# 50%      5.800000    3.000000    4.350000    1.300000    1.000000
# 75%      6.400000    3.300000    5.100000    1.800000    2.000000
# max      7.900000    4.400000    6.900000    2.500000    2.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   150         150 non-null    float64
#  1   4           150 non-null    float64
#  2   setosa      150 non-null    float64
#  3   versicolor  150 non-null    float64
#  4   virginica   150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
df.isnull()
# Out:
#        150      4  setosa  versicolor  virginica
# 0    False  False   False       False      False
# 1    False  False   False       False      False
# 2    False  False   False       False      False
# 3    False  False   False       False      False
# 4    False  False   False       False      False
# ..     ...    ...     ...         ...        ...
# 145  False  False   False       False      False
# 146  False  False   False       False      False
# 147  False  False   False       False      False
# 148  False  False   False       False      False
# 149  False  False   False       False      False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# 150           0
# 4             0
# setosa        0
# versicolor    0
# virginica     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['150', '4', 'setosa', 'versicolor', 'virginica'], dtype='object')

# %%
df.nunique()
# Out:
# 150           35
# 4             23
# setosa        43
# versicolor    22
# virginica      3
# dtype: int64

# %%
df.shape
# Out:
# (150, 5)

# %%
sns.jointplot(x="setosa" , y="virginica" , data=df)
plt.show()

# %%
sns.barplot(x="setosa" , y="virginica" , data=df)
plt.show()

# %%
df.plot(kind='hist')
plt.show()

# %%
df=np.arange(8,13)
df1=np.array([9,10,11,12,13])
print(df)
print(df1)
np.corrcoef(df,df1)
# Out:
# [ 8  9 10 11 12]
# [ 9 10 11 12 13]
# array([[1., 1.],
#        [1., 1.]])

# %%
df=np.arange(15,20)
df1=np.array([10,14,18,22,26])
r=np.corrcoef(df,df1)
r1=scipy.stats.pearsonr(df,df1)
print(r1[0],r1[1])
r2=scipy.stats.spearmanr(df,df1)
print(r2[0],r2[1])
r3=scipy.stats.kendalltau(df,df1)
print([r3[0],r3[1]])
# Out:
# 1.0 0.0
# 0.9999999999999999 1.4042654220543672e-24
# [0.9999999999999999, 0.016666666666666666]

# %%
reg=scipy.stats.linregress(df,df1)
print(reg)
print(reg.slope)
print(reg.rvalue)
print(reg.pvalue)
print(reg.stderr)
print(reg.intercept)
print(reg.intercept_stderr)
# Out:
# LinregressResult(slope=4.0, intercept=-50.0, rvalue=1.0, pvalue=1.2004217548761408e-30, stderr=0.0, intercept_stderr=0.0)
# 4.0
# 1.0
# 1.2004217548761408e-30
# 0.0
# -50.0
# 0.0
